# %% [markdown]
# # LOAD DATA AND PROSSESSING DATA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
data=pd.read_csv('25RP19438.csv')
data
# Out:
#    temperature  crop_yield
# 0           20        1500
# 1           22        1600
# 2           24        1700
# 3           26        1650
# 4           28        1550
# 5           30        1400

# %% [markdown]
#  # Preprocess the Data

# %%
data.columns
# Out:
# Index(['temperature', 'crop_yield'], dtype='object')

# %%
x=data[['temperature']]
y=data['crop_yield']

# %% [markdown]
# # Split the Data

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# # Train the Model

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction =model.predict(x_test)
prediction
# Out:
# array([1925., 1825.])

# %% [markdown]
# # Make Predictions

# %%
y_train_pred = model.predict(x_train)  
y_test_pred=model.predict(x_test)

# %% [markdown]
#  # Evaluate the Model

# %%
MEAN_ERROR = mean_squared_error(y_test,prediction)
MEAN_ERROR
# Out:
# 115624.99999999985

# %%
r2_score_train = r2_score(y_test,prediction)
r2_score
#r2_score_test
# Out:
# <function sklearn.metrics._regression.r2_score(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average', force_finite=True)>

# %% [markdown]
#  # Save the model for future use using your registration number

# %%
import pickle
filename='25rp19438.sav'
pickle.dump(model,open(filename,'wb'))

# %% [markdown]
# # Visualize the Results on training set.

# %%
plt.scatter(x_train,y_train) 
plt.plot(x_train,y_train_pred) 
plt.title('temperture vs crop_yield')
plt.xlabel("Temperature (°C)")
plt.ylabel('crop_yield')
plt.show()

# %% [markdown]
#  # Run your saved model in a new Jupyter notebook file and make predictions
